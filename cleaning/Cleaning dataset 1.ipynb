# %%
#load libraries and data
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv ('innocent_deaths_by_police.csv',low_memory=False)

# %%
#Change column names
df.columns = ['Unique_ID', 'Name', 'Age', 'Gender', 'Race', 'URL_of_image',
       'Date_of_injury_resulting in_death',
       'Location_of_injury_address', 'Location_of_death_city', 'State',
       'Location_of_death_zipcode)', 'Location_of_death_county',
       'Full_Address', 'Latitude', 'Longitude', 'Agencies_involved',
       'Highest_level_of_force', 'Alleged_weapon',
       'Aggressive_physical_movement', 'Fleeing_or_not',
       'Description_Temp', 'URL_Temp', 'Brief_description',
       'Dispositions/Exclusions_INTERNAL_USE_NOT_FOR_ANALYSIS',
       'Intended_use_of_force_Developing', 'Supporting_document_link',
       'Foreknowledge_of_mental_illness']

# %%
df.head()
# Out:
#    Unique_ID                   Name Age  Gender                     Race  \
# 0      25747         Mark A. Horton  21    Male   African-American/Black
# 1      25748  Phillip A. Blurbridge  19    Male   African-American/Black
# 2      25746        Samuel H. Knapp  17    Male  European-American/White
# 3      25749             Mark Ortiz  23    Male          Hispanic/Latino
# 4          1  LaTanya Janelle McCoy  24  Female   African-American/Black
#
#   URL_of_image Date_of_injury_resulting in_death Location_of_injury_address  \
# 0          NaN                          1/1/2000            Davison Freeway
# 1          NaN                          1/1/2000            Davison Freeway
# 2          NaN                          1/1/2000         27898-27804 US-101
# 3          NaN                          1/1/2000            600 W Cherry Ln
# 4          NaN                          1/2/2000       5700 block Mack Road
#
#   Location_of_death_city State  ...  Alleged_weapon  \
# ...
