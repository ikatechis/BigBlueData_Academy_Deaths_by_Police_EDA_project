# %%
import pandas as pd
import numpy as np
import json

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %%
pd.set_option('display.max_rows',25)
pd.set_option('display.max_colwidth', 30)

# %%
with open('../data/data_final_dtypes.json', 'r') as f:
    dtypes = json.load(f)

# %%
dtypes
# Out:
# {'name': 'object',
#  'date': 'object',
#  'state': 'object',
#  'age': 'float64',
#  'age_groups': 'category',
#  'gender': 'category',
#  'race': 'category',
#  'address': 'object',
#  'city': 'object',
#  'latitude': 'float64',
#  'longitude': 'float64',
#  'zipcode': 'float64',
#  'county': 'object',
#  'agency': 'object',
#  'death_cause': 'category',
#  'weapon': 'category',
#  'threat': 'category',
#  'fleeing': 'category',
#  'intended_force': 'category',
#  'encounter_type': 'category',
#  'disposition': 'category',
#  'mental_symptoms': 'category',
#  'description_x': 'object',
#  'description_y': 'object',
#  '_merge': 'category'}

# %%
df = pd.read_csv('../data/data_final.csv', dtype=dtypes)

# %%
df.date = pd.to_datetime(df.date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32510 entries, 0 to 32509
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             32510 non-null  object
#  1   date             32510 non-null  datetime64[ns]
#  2   state            32510 non-null  object
#  3   age              31259 non-null  float64
#  4   age_groups       31259 non-null  category
#  5   gender           32391 non-null  category
#  6   race             23958 non-null  category
#  7   address          31923 non-null  object
#  8   city             32466 non-null  object
#  9   latitude         30820 non-null  float64
#  10  longitude        30821 non-null  float64
#  11  zipcode          32510 non-null  float64
#  12  county           32485 non-null  object
#  13  agency           32430 non-null  object
#  14  death_cause      32345 non-null  category
#  15  weapon           15946 non-null  category
#  16  threat           15406 non-null  category
#  17  fleeing          15310 non-null  category
#  18  intended_force   29910 non-null  category
#  19  encounter_type   3484 non-null   category
#  20  disposition      21165 non-null  category
#  21  mental_symptoms  27464 non-null  category
#  22  description_x    30820 non-null  object
#  23  description_y    9108 non-null   object
#  24  _merge           32510 non-null  category
# dtypes: category(12), datetime64[ns](1), float64(4), object(8)
# memory usage: 3.6+ MB

# %%
df
# Out:
#                                 name       date state   age   age_groups  gender      race                        address              city  latitude  longitude  zipcode      county                         agency death_cause     weapon threat fleeing intended_force encounter_type disposition mental_symptoms                  description_x                  description_y      _merge
# 0                     Mark A. Horton 2000-01-01    MI  21.0  young adult    male     black                Davison Freeway           Detroit   42.4045   -83.0923  48203.0       Wayne                            NaN     vehicle        NaN    NaN     NaN        pursuit            NaN         NaN              no  Two Detroit men killed whe...                            NaN   left_only
# 1              Phillip A. Blurbridge 2000-01-01    MI  19.0  young adult    male     black                Davison Freeway           Detroit   42.4045   -83.0923  48203.0       Wayne                            NaN     vehicle        NaN    NaN     NaN        pursuit            NaN         NaN              no  Two Detroit men killed whe...                            NaN   left_only
# 2                    Samuel H. Knapp 2000-01-01    CA  17.0     teenager    male     white             27898-27804 US-101           Willits   39.4709  -123.3618  95490.0   Mendocino  Mendocino County Sheriff's...     vehicle        NaN    NaN     NaN        pursuit            NaN         NaN              no  Samuel Knapp was allegedly...                            NaN   left_only
# 3                         Mark Ortiz 2000-01-01    NM  23.0  young adult    male  hispanic                600 W Cherry Ln          Carlsbad   32.4501  -104.2376  88220.0        Eddy   Eddy County Sheriff's Office     vehicle        NaN    NaN     NaN        pursuit            NaN         NaN              no  A motorcycle was allegedly...                            NaN   left_only
# 4              LaTanya Janelle McCoy 2000-01-02    CA  24.0  young adult  female     black           5700 block Mack Road        Sacramento   38.4739  -121.4338  95823.0  Sacramento   Sacramento Police Department     vehicle        NaN    NaN     NaN        pursuit            NaN         NaN              no  LaTanya Janelle McCoy's ca...                            NaN   left_only
# ...                              ...        ...   ...   ...          ...     ...       ...                            ...               ...       ...        ...      ...         ...                            ...         ...        ...    ...     ...            ...            ...         ...             ...                            ...                            ...         ...
# 32505                 Jordan Hatcher 2013-01-24    TX  22.0  young adult    male       NaN         2100 Southeast Parkway     Grand Prairie       NaN        NaN  76018.0     Tarrant  Grand Prairie Police Depar...     gunshot  no object    NaN     NaN            NaN            NaN         NaN              no                            NaN  Grand Prairie police respo...  right_only
# 32506                Jayvis Benjamin 2013-01-18    GA  20.0  young adult    male     black  Covington Highway and Kens...  Avondale Estates       NaN        NaN  30002.0      Dekalb  Avondale Estates Police De...     gunshot  no object    NaN     NaN            NaN            NaN   justified              no                            NaN  Police allegedly observed ...  right_only
# 32507                   Jesse France 2013-01-18    WA  29.0  young adult    male     white                7531 NE 18th St         Vancouver       NaN        NaN  98661.0       Clark          U.S. Marshals Service     gunshot    firearm    NaN     NaN            NaN            NaN         NaN              no                            NaN  France was an ex-con who h...  right_only
# 32508  Reginald Lamont “Deucey” Epps 2013-01-18    NC  38.0        adult    male     black              142 Straight Road    Roanoke Rapids       NaN        NaN  27870.0     Halifax  Halifax County Sheriff's O...     gunshot    firearm    NaN     NaN            NaN            NaN         NaN              no                            NaN  County deputies had made s...  right_only
# 32509                  Andrew Layton 2013-01-01    MN  26.0  young adult    male     white         410 S Riverfront Drive           Mankato       NaN        NaN  56001.0  Blue Earth  Mankato Department of Publ...       taser  no object    NaN     NaN            NaN            NaN         NaN              no                            NaN  Former combat medic Layton...  right_only
